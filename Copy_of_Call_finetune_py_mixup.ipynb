# %% [markdown]
# <a href="https://colab.research.google.com/github/nlvtuan/pytorch-finetuner/blob/master/Copy_of_Call_finetune_py_mixup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os.path import join
from google.colab import drive

ROOT = "/content/drive"
drive.mount(ROOT)

from google.colab import drive
drive.mount('/content/drive')

# %cd drive/My\ Drive/DeepLearning/ImageClassificationFelixgwu/pytorch-finetuner
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/DeepLearning/ImageClassificationFelixgwu/pytorch-finetuner

# %%
pip install -U logzero

# %%
pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 225kB 2.8MB/s
# ...

# %%
pip install cnn_finetune
# Out:
# ...
#      |████████████████████████████████| 61kB 4.4MB/s
# ...
#   Created wheel for cnn-finetune: filename=cnn_finetune-0.6.0-cp36-none-any.whl size=11433 sha256=0a38fc15d7c63d215e9d5c14b341adaa4351f8acb37a49172256a444398ebf8a
#   Stored in directory: /root/.cache/pip/wheels/12/4f/29/32978e72b606c5f51b6bd10117814deb46c6b63230eef49381
# ...
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-cp36-none-any.whl size=60963 sha256=d4605185da926e26f612271533c46e468379aca0185da569aafa31a2c7e4a037
#   Stored in directory: /root/.cache/pip/wheels/69/df/63/62583c096289713f22db605aa2334de5b591d59861a02c2ecd
# ...
#   Created wheel for munch: filename=munch-2.3.2-py2.py3-none-any.whl size=6613 sha256=a851e418ecaaa8a2dccc4754656c3e143f343d7b94876352df45779620268078
#   Stored in directory: /root/.cache/pip/wheels/db/bf/bc/06a3e1bfe0ab27d2e720ceb3cff3159398d92644c0cec2c125
# Successfully built cnn-finetune pretrainedmodels munch
# ...

# %%
pip install adabound

# %%
# !python train.py example_images --epochs 5
# Out:
# Running script with args: Namespace(base_lr=0.001, batch_size=128, calc_rgb_mean_and_std=False, cosine_annealing_eta_min=1e-05, cosine_annealing_mult=2, cosine_annealing_t_max=None, cuda=True, cutmix=False, cutmix_beta=1.0, cutmix_prob=1.0, cutout=False, cutout_holes=None, cutout_length=None, data='example_images', disp_batches=1, drop_last=False, epochs=5, final_lr=0.1, icap=False, icap_beta=0.3, image_dump=False, input_size=224, interpolation='BILINEAR', jitter_brightness=0.1, jitter_contrast=0.1, jitter_hue=0.05, jitter_saturation=0.1, log_dir='logs', lr_factor=0.1, lr_patience=None, lr_step_epochs=[10, 20], mixup=False, mixup_alpha=None, model='resnet18', model_dir='model', momentum=0.9, no_cuda=False, optimizer='sgd', prefix='20190829022235', random_erasing=False, random_erasing_p=None, random_erasing_r1=None, random_erasing_r2=None, random_erasing_sh=None, random_erasing_sl=None, random_horizontal_flip=0.5, random_resized_crop_ratio=[0.75, 1.3333333333333333], random_resized_cr
# ...

# %%
# !python train.py Bark101 --mixup --model resnet50 --epochs 300 --base-lr 0.01 --lr-step-epochs 100,200
# Out:
# Running script with args: Namespace(base_lr=0.01, batch_size=128, calc_rgb_mean_and_std=False, cosine_annealing_eta_min=1e-05, cosine_annealing_mult=2, cosine_annealing_t_max=None, cuda=True, cutmix=False, cutmix_beta=1.0, cutmix_prob=1.0, cutout=False, cutout_holes=None, cutout_length=None, data='Bark101', disp_batches=1, drop_last=False, epochs=300, final_lr=0.1, icap=False, icap_beta=0.3, image_dump=False, input_size=224, interpolation='BILINEAR', jitter_brightness=0.1, jitter_contrast=0.1, jitter_hue=0.05, jitter_saturation=0.1, log_dir='logs', lr_factor=0.1, lr_patience=None, lr_step_epochs=[100, 200], mixup=True, mixup_alpha=0.2, model='resnet50', model_dir='model', momentum=0.9, no_cuda=False, optimizer='sgd', prefix='20190829022727', random_erasing=False, random_erasing_p=None, random_erasing_r1=None, random_erasing_r2=None, random_erasing_sh=None, random_erasing_sl=None, random_horizontal_flip=0.5, random_resized_crop_ratio=[0.75, 1.3333333333333333], random_resized_crop_sca
# ...

# %%
# !python test.py example_images -m model/20190826142032-resnet18-best.model
