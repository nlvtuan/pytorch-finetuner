# %% [markdown]
# <a href="https://colab.research.google.com/github/nlvtuan/pytorch-finetuner/blob/master/Call_finetune_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os.path import join
from google.colab import drive

ROOT = "/content/drive"
drive.mount(ROOT)

from google.colab import drive
drive.mount('/content/drive')

# %cd drive/My\ Drive/DeepLearning/ImageClassificationFelixgwu/pytorch-finetuner

# %%
pip install -U logzero

# %%
pip install tensorboardX

# %%
pip install cnn_finetune

# %%
pip install adabound

# %%
# !python train.py example_images --epochs 5

# %%
# !python train.py Bark101 --model resnet50 --epochs 300 --base-lr 0.01 --lr-step-epochs 100,200
# Out:
# Running script with args: Namespace(base_lr=0.01, batch_size=128, calc_rgb_mean_and_std=False, cosine_annealing_eta_min=1e-05, cosine_annealing_mult=2, cosine_annealing_t_max=None, cuda=True, cutmix=False, cutmix_beta=1.0, cutmix_prob=1.0, cutout=False, cutout_holes=None, cutout_length=None, data='Bark101', disp_batches=1, drop_last=False, epochs=300, final_lr=0.1, icap=False, icap_beta=0.3, image_dump=False, input_size=224, interpolation='BILINEAR', jitter_brightness=0.1, jitter_contrast=0.1, jitter_hue=0.05, jitter_saturation=0.1, log_dir='logs', lr_factor=0.1, lr_patience=None, lr_step_epochs=[100, 200], mixup=False, mixup_alpha=None, model='resnet50', model_dir='model', momentum=0.9, no_cuda=False, optimizer='sgd', prefix='20190826165910', random_erasing=False, random_erasing_p=None, random_erasing_r1=None, random_erasing_r2=None, random_erasing_sh=None, random_erasing_sl=None, random_horizontal_flip=0.5, random_resized_crop_ratio=[0.75, 1.3333333333333333], random_resized_crop_s
# ...

# %%
# !python test.py example_images -m model/20190826142032-resnet18-best.model
